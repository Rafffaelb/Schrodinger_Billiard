# 999997  0.435256  0.842452  0.149878  0.234881
# 999998  1.174110  0.045426  0.136512  0.052637
# 999999  0.650032  0.444085  0.635601  0.650742
#
# [1000000 rows x 11 columns]

# %%
Bell_Parameter_Ress_O = df_Bell_Parameter_Ress_O.values
Bell_Parameter_Ress_U = df_Bell_Parameter_Ress_U.values

df_Bell_Parameter_Ress_O[df_Bell_Parameter_Ress_O > 2.0].count()
Violations_O = df_Bell_Parameter_Ress_O[df_Bell_Parameter_Ress_O > 2.0].count().values

# %%
df_Bell_Parameter_Ress_U[df_Bell_Parameter_Ress_U > 2.0].count()
Violations_U = df_Bell_Parameter_Ress_U[df_Bell_Parameter_Ress_U > 2.0].count().values

# %%
print("MAX VALUES OF BELL PARAMETER IN ORTHOGONAL ENSEMBLE")
print(df_Bell_Parameter_Ress_O.max())
print("\n")
print("MAX VALUES OF BELL PARAMETER IN UNITARY ENSEMBLE")
print(df_Bell_Parameter_Ress_U.max())
# Out:
# MAX VALUES OF BELL PARAMETER IN ORTHOGONAL ENSEMBLE
# 0     2.55126
# 1     2.57138
# 2     2.55164
# 3     2.52695
# 4     2.51466
# 5     2.56368
# 6     2.55980
# 7     2.60255
# 8     2.54254
# 9     2.62556
# 10    2.62648
# dtype: float64
#
#
# MAX VALUES OF BELL PARAMETER IN UNITARY ENSEMBLE
# 0     2.52782
# 1     2.71020
# 2     2.58487
# 3     2.58978
# 4     2.58458
# 5     2.57135
# 6     2.55018
# 7     2.57279
# 8     2.52631
# 9     2.56555
# 10    2.52548
# dtype: float64

# %%
fig, axs = plt.subplots(1,2, figsize = (14, 6), constrained_layout = True)

fig.suptitle(r'Histogram of $P(|\mathcal{S}_{CHSH}|)$ for Schrödinger Billiard with 300 resonances', fontsize = 20)

axs[0].hist(Bell_Parameter_Ress_O[:,10], bins = 50, color = 'dodgerblue', label = r'TRS', alpha = 1, histtype = 'bar', ec = 'black')
axs[0].legend(prop = {'size': 20}, bbox_to_anchor = (0.7, 0.97))
axs[0].set_xlabel(r'$|\mathcal{S}_{CHSH}|$', fontsize = 20)
axs[0].tick_params(axis = 'both', which = 'major', labelsize = 20)
axs[0].set_ylabel('$P(|\mathcal{S}_{CHSH}|)$', fontsize = 20)
axs[0].axvline(2, color = 'black')

axs[1].hist(Bell_Parameter_Ress_U[:,10], bins = 50, color = 'red', label = r'No TRS', alpha = 1, histtype = 'bar', ec = 'black')
axs[1].legend(prop = {'size': 20}, bbox_to_anchor = (0.7, 0.97))
axs[1].set_xlabel(r'$|\mathcal{S}_{CHSH}|$', fontsize = 20)
axs[1].tick_params(axis = 'both', which = 'major', labelsize = 20)
axs[1].set_ylabel('$P(|\mathcal{S}_{CHSH}|)$', fontsize = 20)
axs[1].axvline(2, color = 'black')

# %%
for i in range(len(Violations_O)):
    plt.scatter(25*i + 50, (100/1000000)*Violations_O[i], s = 100, color = 'dodgerblue', alpha = 1)
    plt.scatter(25*i + 50, (100/1000000)*Violations_U[i], s = 100, color = 'red', alpha = 1)
    
plt.plot([25*i + 50 for i in range(0,11)], (100/1000000)*Violations_O, label = 'TRS', color = 'dodgerblue', linestyle = '-')
plt.plot([25*i + 50 for i in range(0,11)], (100/1000000)*Violations_U, label = 'No TRS', color = 'red', linestyle = '-')

plt.ylim((0,0.3))

plt.title(r'VIOLATIONS OF BELL INEQUALITY AS FUNCTION OF RESONANCES (N = 2, $\Gamma = 1$)', fontsize = 20)
plt.xlabel('Resonances', fontsize = 15)
plt.ylabel('Violations (%)', fontsize = 19)
plt.tick_params(axis = 'both', which = 'major', labelsize = 15)
plt.grid(linestyle = ':')
plt.legend(fontsize = 15)
plt.figure(figsize = (12,10))

# %%
df_Bell_Parameter_Gamma_O = pd.read_csv(r'Bell_Parameter/Bell_Gamma/Bell_Parameter_O_Gamma.txt', sep = '\t', header = None)
df_Bell_Parameter_Gamma_U = pd.read_csv(r'Bell_Parameter/Bell_Gamma/Bell_Parameter_U_Gamma.txt', sep = '\t', header = None)

# %%
df_Bell_Parameter_Gamma_O.rename(columns = lambda s: (s/20))
# Out:
#             0.00      0.05      0.10      0.15      0.20      0.25      0.30  \
# 0       0.054262  1.364000  0.060939  0.513673  0.108101  0.471283  0.778226
# 1       1.057990  0.665579  0.155639  0.204781  0.682986  0.529577  0.315015
# 2       1.250210  1.690250  0.516732  1.323510  0.436409  0.861702  0.144168
# 3       0.334737  0.488133  0.218619  0.588937  0.572180  0.177026  0.276736
# 4       0.043079  0.383359  0.114912  0.692715  0.603857  1.111830  0.224963
# ...          ...       ...       ...       ...       ...       ...       ...
# 999995  1.924230  0.460479  0.901780  0.719912  1.156810  0.826545  0.221673
# 999996  0.290800  0.908598  0.584851  0.361281  1.201750  0.227137  0.281846
# 999997  0.355576  0.079066  0.419117  1.224330  1.540650  0.229700  0.996904
# 999998  1.071170  0.787955  0.603263  0.093660  0.396624  0.157404  0.677449
# 999999  1.178300  0.260512  0.795088  0.985074  0.726149  1.137040  1.882310
#
#             0.35      0.40      0.45  ...      0.55      0.60      0.65  \
# 0       0.092076  0.356856  0.425701  ...  0.947220  0.679675  0.366610
# 1       0.459520  0.877752  0.751713  ...  0.915946  0.485971  0.107885
# 2       0.014098  0.471222  0.595614  ...  0.581498  1.038580  0.236654
# 3       0.429288  0.487520  1.013740  ...  0.383905  0.698205  0.553976
# 4       0.521211  0.837740  0.599629  ...  0.113375  0.363840  0.453955
# ...          ...       ...       ...  ...       ...       ...       ...
# 999995  0.624881  0.731188  0.206517  ...  0.126167  0.453620  0.809420
# 999996  0.238990  0.924884  0.718669  ...  0.465169  0.270103  0.059941
# 999997  0.549821  0.633010  0.571681  ...  0.585418  0.149484  0.786868
# 999998  0.696767  0.545140  0.331804  ...  0.443068  0.564316  0.575396
# 999999  0.025451  0.435589  0.835810  ...  0.620036  0.431623  0.159982
#
#             0.70      0.75      0.80      0.85      0.90      0.95      1.00
# 0       0.285408  0.179281  0.328538  0.081003  1.839120  0.797574  0.095715
# 1       0.013147  0.835395  1.250540  0.571107  0.975096  0.163911  1.422710
# 2       0.097036  0.261472  0.096542  0.505660  0.300508  1.005830  0.284756
# 3       1.219190  0.789317  0.716522  0.410281  0.995729  0.914973  0.184267
# 4       0.767671  0.039161  0.437620  0.319108  0.086431  0.524687  1.506030
# ...          ...       ...       ...       ...       ...       ...       ...
# 999995  0
print(df_Bell_Parameter_Gamma_O.max())
print("\n")
print("MAX VALUES OF BELL PARAMETER IN UNITARY ENSEMBLE")
print(df_Bell_Parameter_Gamma_U.max())
# Out:
# MAX VALUES OF BELL PARAMETER IN ORTHOGONAL ENSEMBLE
# 0     2.51841
# 1     2.54842
# 2     2.56685
# 3     2.63018
# 4     2.65822
# 5     2.55852
# 6     2.62165
# 7     2.65094
# 8     2.60119
# 9     2.62056
# 10    2.61562
# 11    2.58054
# 12    2.61700
# 13    2.60059
# 14    2.55730
# 15    2.61199
# 16    2.75537
# 17    2.64329
# 18    2.56256
# 19    2.61809
# 20    2.56279
# dtype: float64
#
#
# MAX VALUES OF BELL PARAMETER IN UNITARY ENSEMBLE
# 0     2.57516
# 1     2.60253
# 2     2.62516
# 3     2.71368
# 4     2.48901
# 5     2.55411
# 6     2.53650
# 7     2.54421
# 8     2.56758
# 9     2.62572
# 10    2.59955
# 11    2.55563
# 12    2.52193
# 13    2.56246
# 14    2.50398
# 15    2.60363
# 16    2.53397
# 17    2.55707
# 18    2.54333
# 19    2.59587
# 20    2.53496
# dtype: float64

# %%
Violations_Gamma_O = df_Bell_Parameter_Gamma_O[df_Bell_Parameter_Gamma_O > 2.0].count().values
print(df_Bell_Parameter_Gamma_O[df_Bell_Parameter_Gamma_O > 2.0].count())
print("\n")
Violations_Gamma_U = df_Bell_Parameter_Gamma_U[df_Bell_Parameter_Gamma_O > 2.0].count().values
print(df_Bell_Parameter_Gamma_U[df_Bell_Parameter_Gamma_U > 2.0].count())
# Out:
# 0     1216
# 1     1204
# 2     1186
# 3     1223
# 4     1246
# 5     1189
# 6     1196
# 7     1206
# 8     1183
# 9     1154
# 10    1232
# 11    1217
# 12    1204
# 13    1247
# 14    1228
# 15    1287
# 16    1198
# 17    1212
# 18    1156
# 19    1191
# 20    1217
# dtype: int64
#
#
# 0     1158
# 1     1205
# 2     1140
# 3     1139
# 4     1158
# 5     1116
# 6     1191
# 7     1119
# 8     1142
# 9     1120
# 10    1185
# 11    1104
# 12    1141
# 13    1117
# 14    1102
# 15    1131
# 16    1156
# 17    1149
# 18    1064
# 19    1175
# 20    1122
# dtype: int64

# %%
for i in range(len(Violations_Gamma_O)):
    plt.scatter(i/20, (100/1000000)*Violations_Gamma_O[i], s = 150, color = 'dodgerblue', alpha = 1)
    plt.scatter(i/20, (100/1000000)*Violations_Gamma_U[i], s = 100, color = 'red', alpha = 1)
    
plt.plot([(i/20) for i in range(0,21)], (100/1000000)*Violations_Gamma_O, label = 'TRS', color = 'dodgerblue', linestyle = '-')
plt.plot([(i/20) for i in range(0,21)], (100/1000000)*Violations_Gamma_U, label = 'No TRS', color = 'red', linestyle = '-')

plt.ylim((0,0.3))

plt.title(r'VIOLATIONS OF BELL INEQUALITY AS FUNCTION OF $\Gamma$', fontsize = 20)
plt.xlabel(r'$\Gamma$', fontsize = 15)
plt.ylabel('Violations (%)', fontsize = 19)
plt.tick_params(axis = 'both', which = 'major', labelsize = 15)
plt.grid(linestyle = ':')
plt.legend(fontsize = 15)
plt.figure(figsize = (12,10))
